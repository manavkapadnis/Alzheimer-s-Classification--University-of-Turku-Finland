# %%
# importing all the required Libraries
from collections import Counter
import cv2
import os
import glob
import skimage
import numpy as np
import pandas as pd
import seaborn as sn
from tqdm import tqdm
from PIL import Image
import random

from os import listdir
import matplotlib.pyplot as plt
from skimage.transform import resize
from collections import Counter
import pickle

sn.set()

from sklearn.svm import SVC # SVC
from sklearn import metrics
from sklearn.utils import shuffle
from xgboost import XGBClassifier # XGBClassifier
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils import compute_class_weight
from sklearn.preprocessing import MinMaxScaler,LabelBinarizer,OneHotEncoder
from sklearn.ensemble import AdaBoostClassifier # AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier # KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier # RandomForestClassifier
from sklearn.model_selection import train_test_split

from sklearn.svm import SVC # SVC
from sklearn import metrics
from sklearn.utils import shuffle
from xgboost import XGBClassifier # XGBClassifier
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils import compute_class_weight
from sklearn.preprocessing import MinMaxScaler,LabelBinarizer,OneHotEncoder
from sklearn.ensemble import AdaBoostClassifier # AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier # KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier # RandomForestClassifier
from sklearn.model_selection import train_test_split

import tensorflow 
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import AUC
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, Flatten, Activation, GlobalAveragePooling2D,Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import grey2rgb

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPooling2D, Conv2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import optimizers

from tensorflow.keras.callbacks import Callback,ModelCheckpoint
from tensorflow.keras.models import Sequential,load_model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
import tensorflow.keras.backend as K

import tensorflow 
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import AUC
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications.vgg16 import VGG16 # VGG16
from tensorflow.keras.applications.vgg19 import VGG19 # VGG19
from tensorflow.keras.applications.resnet50 import ResNet50 # ResNet50
from tensorflow.keras.applications import ResNet101,InceptionResNetV2 # ResNet 101
from tensorflow.keras.applications.xception import Xception # Xception
from tensorflow.keras.applications.mobilenet import MobileNet # MobileNet
from tensorflow.keras.applications.densenet import DenseNet169 # DenseNet169
from tensorflow.keras.applications.densenet import DenseNet121 # DenseNet121
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2 # MobileNetV2
from tensorflow.keras.applications.inception_v3 import InceptionV3 # InceptionV3
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, Flatten, Activation, GlobalAveragePooling2D,Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
pickle_in = open(r"C:/Users/iamma/Desktop/University of Finland/Dataset/X.pickle","rb")
X = pickle.load(pickle_in)
pickle_in.close()

pickle_in = open(r"C:/Users/iamma/Desktop/University of Finland/Dataset/y.pickle","rb")
y = pickle.load(pickle_in)
pickle_in.close()

pickle_in = open(r"C:/Users/iamma/Desktop/University of Finland/Dataset/X_test.pickle","rb")
X_test = pickle.load(pickle_in)
pickle_in.close()

pickle_in = open(r"C:/Users/iamma/Desktop/University of Finland/Dataset/y_test.pickle","rb")
y_test = pickle.load(pickle_in)
pickle_in.close()

# %%
base_model = DenseNet169(include_top=False, weights='imagenet', input_shape=(224,224,3))

# %%
x = base_model.output
x = Dropout(0.5)(x)
x = Flatten()(x)
x = BatchNormalization()(x)
x = Dense(64,kernel_initializer='he_uniform')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)
x = Dense(64,kernel_initializer='he_uniform')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)
x = Dense(64,kernel_initializer='he_uniform')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)
x = Dense(32,kernel_initializer='he_uniform')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)
x = Dense(32,kernel_initializer='he_uniform')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)
x = Dense(32,kernel_initializer='he_uniform')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)

predictions = Dense(4, activation='softmax')(x)
model_feat = Model(inputs=base_model.input,outputs=predictions)

train_features = model_feat.predict(X)
test_features=model_feat.predict(X_test)

# %%
model = Sequential()
model.add(Dense(units=4, activation='relu',input_shape=(5120,4)))
model.add(Dense(units=8, activation='relu'))
model.add(Dense(units=16, activation='relu'))
model.add(Dense(units=4))
model.add(Activation('softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 5120, 4)           20
# _________________________________________________________________
# dense_8 (Dense)              (None, 5120, 8)           40
# _________________________________________________________________
# dense_9 (Dense)              (None, 5120, 16)          144
# _________________________________________________________________
# dense_10 (Dense)             (None, 5120, 4)           68
# _________________________________________________________________
# activation_6 (Activation)    (None, 5120, 4)           0
# =================================================================
# Total params: 272
# Trainable params: 272
# Non-trainable params: 0
# _________________________________________________________________

# %%
def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
        f1_score,
]

# %%
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.01, 5) # when i run it for 50 epochs

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

# %%
onehot = LabelBinarizer()
y_1 = onehot.fit_transform(y)
y_test_1  = onehot.transform(y_test)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(
    learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07, amsgrad=False,
    name='Adam',), loss='categorical_crossentropy',metrics=METRICS)

# %%
history = model.fit(train_features, y_1, epochs=20,batch_size=32,validation_split=0.2)
# Out:
# Epoch 1/20
# WARNING:tensorflow:Model was constructed with shape (None, 5120, 4) for input KerasTensor(type_spec=TensorSpec(shape=(None, 5120, 4), dtype=tf.float32, name='dense_7_input'), name='dense_7_input', description="created by layer 'dense_7_input'"), but it was called on an input with incompatible shape (32, 4).
# WARNING:tensorflow:Model was constructed with shape (None, 5120, 4) for input KerasTensor(type_spec=TensorSpec(shape=(None, 5120, 4), dtype=tf.float32, name='dense_7_input'), name='dense_7_input', description="created by layer 'dense_7_input'"), but it was called on an input with incompatible shape (32, 4).
# 111/128 [=========================>....] - ETA: 0s - loss: 1.3075 - accuracy: 0.7500 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6793 - f1_score: 0.0000e+00WARNING:tensorflow:Model was constructed with shape (None, 5120, 4) for input KerasTensor(type_spec=TensorSpec(shape=(None, 5120, 4), dtype=tf.float32, name='dense_7_input'), name='dense_7_input', description="created by layer 'dense_7_input'"), but it was called on an input with incompatible shape (None, 4).
# 128/128 [==============================] - 3s 11ms/step - loss: 1.2949 - accuracy: 0.7500 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6881 - f1_score: 0.0000e+00 - val_loss: 1.0498 - val_accuracy: 0.7500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7935 - val_f1_score: 0.0000e+00
# Epoch 2/20
# 128/128 [==============================] - 0s 1ms/step - loss: 1.0680 - accuracy: 0.7497 - precision: 0.3077 - recall: 0.0678 - auc: 0.7734 - f1_score: 0.0678 - val_loss: 1.0123 - val_accuracy: 0.7500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7935 - val_f1_score: 0.0000e+00
# Epoch 3/20
# 128/128 [==============================] - 0s 1ms/step - loss: 1.0458 - accuracy: 0.7502 - precision: 0.1474 - recall: 0.0238 - auc: 0.7716 - f1_score: 0.0238 - val_loss: 1.0075 - val_accuracy: 0.7500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7935 - val_f1_score: 0.0000e+00
# Epoch 4/20
# 128/128 [==============================] - 0s 1ms/step - loss: 1.0319 - accuracy: 0.7497 - precision: 0.2756 - recall: 0.0794 - auc: 0.7776 - f1_score: 0.0794 - val_loss: 1.0089 - val_accuracy: 0.7500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7934 - val_f1_score: 0.0000e+00
# Epoch 5/20
# 128/128 [==============================] - 0s 1ms/step - loss: 1.0401 - accuracy: 0.7497 - precision: 0.1362 - recall: 0.0048 - auc: 0.7728 - f1_score: 0.0048 - val_loss: 1.0059 - val_accuracy: 0.7500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7935 - val_f1_score: 0.0000e+00
# Epoch 6/20
# 128/128 [==============================] - 0s 1ms/step - loss: 1.0469 - accuracy: 0.7410 - precision: 0.4456 - recall: 0.1734 - auc: 0.7712 - f1_score: 0.1734 - val_loss: 1.0048 - val_accuracy: 0.7620 - val_precision: 0.5239 - val_recall: 0.5239 - val_auc: 0.7935 - val_f1_score: 0.5379
# Epoch 7/20
# 128/128 [==============================] - 0s 1ms/step - loss: 1.0345 - accuracy: 0.7484 - precision: 0.4863 - recall: 0.1410 - auc: 0.7774 - f1_score: 0.1412 - val_loss: 1.0054 - val_accuracy: 0.7500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7935 - val_f1_score: 0.0000e+00
# Epoch 8/20
# 128/128 [==============================] - 0s 1ms/step - loss: 1.0341 - accuracy: 0.7478 - precision: 0.4346 - recall: 0.0663 - auc: 0.7754 - f1_score: 0.0663 - val_loss: 1.0059 - val_accuracy: 0.7620 - val_precision: 0.5239 - val_recall: 0.5239 - val_auc: 0.7935 - val_f1_score: 0.5379
# Epoch 9/20
# 128/128 [==============================] - 0s 1ms/step - loss: 1.0300 - accuracy: 0.7507 - precision: 0.4981 - recall: 0.2043 - auc: 0.7805 - f1_score: 0.2043 - val_loss: 1.0079 - val_accuracy: 0.7500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7935 - val_f1_score: 0.0000e+00
# Epoch 10/20
# 128/128 [==============================] - 0s 1ms/step - loss: 1.0404 - accuracy: 0.7501 - precision: 0.2397 - recall: 0.0599 - auc: 0.7750 - f1_score: 0.0599 - val_loss: 1.0089 - val_accuracy: 0.7500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7935 - val_f1_score: 0.0000e+00
# Epoch 11/20
# 128/128 [==============================] - 0s 1ms/step - loss: 1.0433 - accuracy: 0.7498 - precision: 0.2351 - recall: 0.0474 - auc: 0.7745 - f1_score: 0.0474 - val_loss: 1.0084 - val_accuracy: 0.7500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7935 - val_f1_score: 0.0000e+00
# Epoch 12/20
# 128/128 [==============================] - 0s 1ms/step - loss: 1.0406 - accuracy: 0.7500 - precision: 0.0586 - recall: 0.0038 - auc: 0.7728 - f1_score: 0.0038 - val_loss: 1.0042 - val_accuracy: 0.7620 - val_precision: 0.5239 - val_recall: 0.5239 - val_auc: 0.7935 - val_f1_score: 0.5379
# Epoch 13/20
# 128/128 [==============================] - 0s 1ms/step - loss: 1.0466 - accuracy: 0.7476 - precision: 0.4897 - recall: 0.2805 - auc: 0.7753 - f1_score: 0.2805 - val_loss: 1.0065 - val_accuracy: 0.7500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7935 - val_f1_score: 0.0000e+00
# Epoch 14/20
# 128/128 [==============================] - 0s 1ms/step - loss: 1.0368 - accuracy: 0.7500 - precision: 0.2580 - recall: 0.0768 - auc: 0.7728 - f1_score: 0.0768 - val_loss: 1.0055 - val_accuracy: 0.7500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7935 - val_f1_score: 0.0000e+00
# Epoch 15/20
# 128/128 [==============================] - 0s 1ms/step - loss: 1.0453 - accuracy: 0.7475 - precision: 0.3898 - recall: 0.1088 - auc: 0.7763 - f1_score: 0.1088 - val_loss: 1.0059 - val_accuracy: 0.7500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7935 - val_f1_score: 0.0000e+00
# Epoch 16/20
# 128/128 [==============================] - 0s 1ms/step - loss: 1.0531 - accuracy: 0.7491 - precision: 0.2246 - recall: 0.0434 - auc: 0.7693 - f1_score: 0.0434 - val_loss: 1.0058 - val_accuracy: 0.7500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7935 - val_f1_score: 0.0000e+00
# Epoch 17/20
# 128/128 [==============================] - 0s 1ms/step - loss: 1.0343 - accuracy: 0.7487 - precision: 0.4745 - recall: 0.2658 - auc: 0.7789 - f1_score: 0.2658 - val_loss: 1.0074 - val_accuracy: 0.7500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7935 - val_f1_score: 0.0000e+00
# Epoch 18/20
# 128/128 [==============================] - 0s 1ms/step - loss: 1.0374 - accuracy: 0.7492 - precision: 0.3824 - recall: 0.1068 - auc: 0.7781 - f1_score: 0.1068 - val_loss: 1.0063 - val_accuracy: 0.7500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7935 - val_f1_score: 0.0000e+00
# Epoch 19/20
# 128/128 [==============================] - 0s 1ms/step - loss: 1.0337 - accuracy: 0.7476 - precision: 0.4762 - recall: 0.2254 - auc: 0.7764 - f1_score: 0.2254 - val_loss: 1.0052 - val_accuracy: 0.7500 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7935 - val_f1_score: 0.0000e+00
# Epoch 20/20
# 128/128 [==============================] - 0s 1ms/step - loss: 1.0434 - accuracy: 0.7511 - precision: 0.4866 - recall: 0.3327 - auc: 0.7799 - f1_score: 0.3327 - val_loss: 1.0053 - val_accuracy: 0.7620 - val_precision: 0.5239 - val_recall: 0.5239 - val_auc: 0.7935 - val_f1_score: 0.5379

# %%
model.evaluate(test_features,y_test_1)
# Out:
# 40/40 [==============================] - 0s 811us/step - loss: 1.0333 - accuracy: 0.7502 - precision: 0.5004 - recall: 0.5004 - auc: 0.7806 - f1_score: 0.5004
# [1.033323884010315,
#  0.7501954436302185,
#  0.5003909468650818,
#  0.5003909468650818,
#  0.7805577516555786,
#  0.5003527402877808]

# %%
#%% PLOTTING RESULTS (Train vs Validation FOLDER 1)

def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1,val_f1):
    
    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])
    
    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])
    
    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])
    
    ax5.plot(range(1, len(f1) + 1), f1)
    ax5.plot(range(1, len(val_f1) + 1), val_f1)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.legend(['training', 'validation'])


    plt.show()
    

Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'],
               history.history['auc'],history.history['val_auc'],
               history.history['precision'],history.history['val_precision'],
               history.history['f1_score'],history.history['val_f1_score']
              )
