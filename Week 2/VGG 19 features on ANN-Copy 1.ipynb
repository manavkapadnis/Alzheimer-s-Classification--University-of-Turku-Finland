# %%
# importing all the required Libraries
from collections import Counter
import cv2
import os
import glob
import skimage
import numpy as np
import pandas as pd
import seaborn as sn
from tqdm import tqdm
from PIL import Image
import random

from os import listdir
import matplotlib.pyplot as plt
from skimage.transform import resize
from collections import Counter
import pickle

sn.set()

from sklearn.svm import SVC # SVC
from sklearn import metrics
from sklearn.utils import shuffle
from xgboost import XGBClassifier # XGBClassifier
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils import compute_class_weight
from sklearn.preprocessing import MinMaxScaler,LabelBinarizer,OneHotEncoder
from sklearn.ensemble import AdaBoostClassifier # AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier # KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier # RandomForestClassifier
from sklearn.model_selection import train_test_split


import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPooling2D, Conv2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import optimizers
from skimage.transform import resize
from collections import Counter
import pickle

sn.set()

from sklearn.svm import SVC # SVC
from sklearn import metrics
from sklearn.utils import shuffle
from xgboost import XGBClassifier # XGBClassifier
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils import compute_class_weight
from sklearn.preprocessing import MinMaxScaler,LabelBinarizer,OneHotEncoder
from sklearn.ensemble import AdaBoostClassifier # AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier # KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier # RandomForestClassifier
from sklearn.model_selection import train_test_split

import tensorflow 
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import AUC
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, Flatten, Activation, GlobalAveragePooling2D,Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import grey2rgb

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPooling2D, Conv2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import optimizers

from tensorflow.keras.callbacks import Callback,ModelCheckpoint
from tensorflow.keras.models import Sequential,load_model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
import tensorflow.keras.backend as K

import tensorflow 
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import AUC
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications.vgg16 import VGG16 # VGG16
from tensorflow.keras.applications.vgg19 import VGG19 # VGG19
from tensorflow.keras.applications.resnet50 import ResNet50 # ResNet50
from tensorflow.keras.applications import ResNet101,InceptionResNetV2 # ResNet 101
from tensorflow.keras.applications.xception import Xception # Xception
from tensorflow.keras.applications.mobilenet import MobileNet # MobileNet
from tensorflow.keras.applications.densenet import DenseNet169 # DenseNet169
from tensorflow.keras.applications.densenet import DenseNet121 # DenseNet121
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2 # MobileNetV2
from tensorflow.keras.applications.inception_v3 import InceptionV3 # InceptionV3
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, Flatten, Activation, GlobalAveragePooling2D,Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
pickle_in = open(r"C:/Users/iamma/Desktop/University of Finland/Dataset/X.pickle","rb")
X = pickle.load(pickle_in)
pickle_in.close()

pickle_in = open(r"C:/Users/iamma/Desktop/University of Finland/Dataset/y.pickle","rb")
y = pickle.load(pickle_in)
pickle_in.close()

pickle_in = open(r"C:/Users/iamma/Desktop/University of Finland/Dataset/X_test.pickle","rb")
X_test = pickle.load(pickle_in)
pickle_in.close()

pickle_in = open(r"C:/Users/iamma/Desktop/University of Finland/Dataset/y_test.pickle","rb")
y_test = pickle.load(pickle_in)
pickle_in.close()

# %%
base_model = VGG19(include_top=False, weights='imagenet', input_shape=(224,224,3))

# %%
x = base_model.output
x = Dropout(0.5)(x)
x = Flatten()(x)
x = BatchNormalization()(x)
x = Dense(64,kernel_initializer='he_uniform')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)
x = Dense(64,kernel_initializer='he_uniform')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)
x = Dense(64,kernel_initializer='he_uniform')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)
x = Dense(32,kernel_initializer='he_uniform')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)
x = Dense(32,kernel_initializer='he_uniform')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)
x = Dense(32,kernel_initializer='he_uniform')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)

predictions = Dense(4, activation='softmax')(x)
model_feat = Model(inputs=base_model.input,outputs=predictions)

train_features = model_feat.predict(X)
test_features=model_feat.predict(X_test)

# %%
model = Sequential()
model.add(Dense(units=4, activation='relu',input_shape=(5120,4)))
model.add(Dense(units=8, activation='relu'))
model.add(Dense(units=16, activation='relu'))
model.add(Dense(units=4))
model.add(Activation('softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_14 (Dense)             (None, 5120, 4)           20
# _________________________________________________________________
# dense_15 (Dense)             (None, 5120, 8)           40
# _________________________________________________________________
# dense_16 (Dense)             (None, 5120, 16)          144
# _________________________________________________________________
# dense_17 (Dense)             (None, 5120, 4)           68
# _________________________________________________________________
# activation_12 (Activation)   (None, 5120, 4)           0
# =================================================================
# Total params: 272
# Trainable params: 272
# Non-trainable params: 0
# _________________________________________________________________

# %%
def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
        f1_score,
]

# %%
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.01, 5) # when i run it for 50 epochs

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

# %%
onehot = LabelBinarizer()
y_1 = onehot.fit_transform(y)
y_test_1  = onehot.transform(y_test)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(
    learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07, amsgrad=False,
    name='Adam',), loss='categorical_crossentropy',metrics=METRICS)

# %%
history = model.fit(train_features, y_1, epochs=20,batch_size=32,validation_split=0.2)
# Out:
# Epoch 1/20
# WARNING:tensorflow:Model was constructed with shape (None, 5120, 4) for input KerasTensor(type_spec=TensorSpec(shape=(None, 5120, 4), dtype=tf.float32, name='dense_14_input'), name='dense_14_input', description="created by layer 'dense_14_input'"), but it was called on an input with incompatible shape (32, 4).
# WARNING:tensorflow:Model was constructed with shape (None, 5120, 4) for input KerasTensor(type_spec=TensorSpec(shape=(None, 5120, 4), dtype=tf.float32, name='dense_14_input'), name='dense_14_input', description="created by layer 'dense_14_input'"), but it was called on an input with incompatible shape (32, 4).
# 113/128 [=========================>....] - ETA: 0s - loss: 1.3360 - accuracy: 0.7500 - precision: 0.0294 - recall: 1.2349e-04 - auc: 0.6180 - f1_score: 2.0178e-04    WARNING:tensorflow:Model was constructed with shape (None, 5120, 4) for input KerasTensor(type_spec=TensorSpec(shape=(None, 5120, 4), dtype=tf.float32, name='dense_14_input'), name='dense_14_input', description="created by layer 'dense_14_input'"), but it was called on an input with incompatible shape (None, 4).
# 128/128 [==============================] - 3s 9ms/step - loss: 1.3258 - accuracy: 0.7502 - precision: 0.0986 - recall: 0.0020 - auc: 0.6327 - f1_score: 0.0031 - val_loss: 1.0972 - val_accuracy: 0.7661 - val_precision: 0.6019 - val_recall: 0.1902 - val_auc: 0.7939 - val_f1_score: 0.2786
# Epoch 2/20
# 128/128 [==============================] - 0s 2ms/step - loss: 1.0743 - accuracy: 0.7645 - precision: 0.5915 - recall: 0.1895 - auc: 0.7903 - f1_score: 0.2827 - val_loss: 1.0242 - val_accuracy: 0.7656 - val_precision: 0.5884 - val_recall: 0.2078 - val_auc: 0.8009 - val_f1_score: 0.2958
# Epoch 3/20
# 128/128 [==============================] - 0s 2ms/step - loss: 1.0612 - accuracy: 0.7608 - precision: 0.5648 - recall: 0.1897 - auc: 0.7816 - f1_score: 0.2824 - val_loss: 1.0105 - val_accuracy: 0.7659 - val_precision: 0.5915 - val_recall: 0.2049 - val_auc: 0.8000 - val_f1_score: 0.2933
# Epoch 4/20
# 128/128 [==============================] - 0s 2ms/step - loss: 1.0463 - accuracy: 0.7586 - precision: 0.5532 - recall: 0.1822 - auc: 0.7814 - f1_score: 0.2712 - val_loss: 1.0034 - val_accuracy: 0.7656 - val_precision: 0.5874 - val_recall: 0.2098 - val_auc: 0.8046 - val_f1_score: 0.2978
# Epoch 5/20
# 128/128 [==============================] - 0s 2ms/step - loss: 1.0443 - accuracy: 0.7577 - precision: 0.5493 - recall: 0.1735 - auc: 0.7816 - f1_score: 0.2614 - val_loss: 1.0016 - val_accuracy: 0.7659 - val_precision: 0.5910 - val_recall: 0.2059 - val_auc: 0.8043 - val_f1_score: 0.2943
# Epoch 6/20
# 128/128 [==============================] - 0s 2ms/step - loss: 1.0548 - accuracy: 0.7573 - precision: 0.5462 - recall: 0.1711 - auc: 0.7770 - f1_score: 0.2589 - val_loss: 1.0003 - val_accuracy: 0.7661 - val_precision: 0.5927 - val_recall: 0.2059 - val_auc: 0.8041 - val_f1_score: 0.2945
# Epoch 7/20
# 128/128 [==============================] - 0s 2ms/step - loss: 1.0523 - accuracy: 0.7571 - precision: 0.5445 - recall: 0.1730 - auc: 0.7784 - f1_score: 0.2598 - val_loss: 0.9993 - val_accuracy: 0.7654 - val_precision: 0.5858 - val_recall: 0.2098 - val_auc: 0.8043 - val_f1_score: 0.2977
# Epoch 8/20
# 128/128 [==============================] - 0s 2ms/step - loss: 1.0441 - accuracy: 0.7627 - precision: 0.5781 - recall: 0.1891 - auc: 0.7833 - f1_score: 0.2823 - val_loss: 1.0028 - val_accuracy: 0.7668 - val_precision: 0.6049 - val_recall: 0.1941 - val_auc: 0.8036 - val_f1_score: 0.2835
# Epoch 9/20
# 128/128 [==============================] - 0s 2ms/step - loss: 1.0418 - accuracy: 0.7558 - precision: 0.5379 - recall: 0.1655 - auc: 0.7788 - f1_score: 0.2507 - val_loss: 0.9985 - val_accuracy: 0.7654 - val_precision: 0.5836 - val_recall: 0.2146 - val_auc: 0.8047 - val_f1_score: 0.3025
# Epoch 10/20
# 128/128 [==============================] - 0s 2ms/step - loss: 1.0439 - accuracy: 0.7576 - precision: 0.5441 - recall: 0.1872 - auc: 0.7810 - f1_score: 0.2762 - val_loss: 1.0026 - val_accuracy: 0.7671 - val_precision: 0.6061 - val_recall: 0.1951 - val_auc: 0.8039 - val_f1_score: 0.2847
# Epoch 11/20
# 128/128 [==============================] - 0s 2ms/step - loss: 1.0381 - accuracy: 0.7652 - precision: 0.5980 - recall: 0.1862 - auc: 0.7877 - f1_score: 0.2812 - val_loss: 1.0057 - val_accuracy: 0.7661 - val_precision: 0.6093 - val_recall: 0.1795 - val_auc: 0.8037 - val_f1_score: 0.2673
# Epoch 12/20
# 128/128 [==============================] - 0s 2ms/step - loss: 1.0390 - accuracy: 0.7584 - precision: 0.5585 - recall: 0.1626 - auc: 0.7832 - f1_score: 0.2492 - val_loss: 0.9999 - val_accuracy: 0.7659 - val_precision: 0.5926 - val_recall: 0.2029 - val_auc: 0.8038 - val_f1_score: 0.2913
# Epoch 13/20
# 128/128 [==============================] - 0s 2ms/step - loss: 1.0541 - accuracy: 0.7551 - precision: 0.5323 - recall: 0.1654 - auc: 0.7758 - f1_score: 0.2483 - val_loss: 0.9994 - val_accuracy: 0.7656 - val_precision: 0.5874 - val_recall: 0.2098 - val_auc: 0.8039 - val_f1_score: 0.2978
# Epoch 14/20
# 128/128 [==============================] - 0s 2ms/step - loss: 1.0348 - accuracy: 0.7613 - precision: 0.5753 - recall: 0.1731 - auc: 0.7866 - f1_score: 0.2627 - val_loss: 0.9992 - val_accuracy: 0.7661 - val_precision: 0.5912 - val_recall: 0.2088 - val_auc: 0.8042 - val_f1_score: 0.2973
# Epoch 15/20
# 128/128 [==============================] - 0s 2ms/step - loss: 1.0389 - accuracy: 0.7597 - precision: 0.5598 - recall: 0.1812 - auc: 0.7841 - f1_score: 0.2704 - val_loss: 1.0015 - val_accuracy: 0.7668 - val_precision: 0.6036 - val_recall: 0.1961 - val_auc: 0.8050 - val_f1_score: 0.2856
# Epoch 16/20
# 128/128 [==============================] - 0s 2ms/step - loss: 1.0367 - accuracy: 0.7569 - precision: 0.5452 - recall: 0.1651 - auc: 0.7815 - f1_score: 0.2505 - val_loss: 0.9999 - val_accuracy: 0.7666 - val_precision: 0.5994 - val_recall: 0.2000 - val_auc: 0.8044 - val_f1_score: 0.2890
# Epoch 17/20
# 128/128 [==============================] - 0s 2ms/step - loss: 1.0297 - accuracy: 0.7593 - precision: 0.5600 - recall: 0.1748 - auc: 0.7869 - f1_score: 0.2625 - val_loss: 1.0008 - val_accuracy: 0.7673 - val_precision: 0.6060 - val_recall: 0.1980 - val_auc: 0.8048 - val_f1_score: 0.2879
# Epoch 18/20
# 128/128 [==============================] - 0s 2ms/step - loss: 1.0372 - accuracy: 0.7580 - precision: 0.5523 - recall: 0.1694 - auc: 0.7843 - f1_score: 0.2562 - val_loss: 1.0000 - val_accuracy: 0.7666 - val_precision: 0.5988 - val_recall: 0.2010 - val_auc: 0.8049 - val_f1_score: 0.2900
# Epoch 19/20
# 128/128 [==============================] - 0s 2ms/step - loss: 1.0553 - accuracy: 0.7555 - precision: 0.5364 - recall: 0.1628 - auc: 0.7772 - f1_score: 0.2469 - val_loss: 0.9980 - val_accuracy: 0.7659 - val_precision: 0.5867 - val_recall: 0.2146 - val_auc: 0.8043 - val_f1_score: 0.3028
# Epoch 20/20
# 128/128 [==============================] - 0s 2ms/step - loss: 1.0362 - accuracy: 0.7582 - precision: 0.5541 - recall: 0.1686 - auc: 0.7808 - f1_score: 0.2560 - val_loss: 0.9996 - val_accuracy: 0.7661 - val_precision: 0.5912 - val_recall: 0.2088 - val_auc: 0.8049 - val_f1_score: 0.2973

# %%
model.evaluate(test_features,y_test_1)
# Out:
# 40/40 [==============================] - 0s 1ms/step - loss: 1.0152 - accuracy: 0.7756 - precision: 0.5677 - recall: 0.4292 - auc: 0.8012 - f1_score: 0.4869
# [1.0151530504226685,
#  0.7756059169769287,
#  0.5677352547645569,
#  0.4292415976524353,
#  0.8012316823005676,
#  0.4869028627872467]

# %%
#%% PLOTTING RESULTS (Train vs Validation FOLDER 1)

def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1,val_f1):
    
    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])
    
    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])
    
    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])
    
    ax5.plot(range(1, len(f1) + 1), f1)
    ax5.plot(range(1, len(val_f1) + 1), val_f1)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.legend(['training', 'validation'])


    plt.show()
    

Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'],
               history.history['auc'],history.history['val_auc'],
               history.history['precision'],history.history['val_precision'],
               history.history['f1_score'],history.history['val_f1_score']
              )
